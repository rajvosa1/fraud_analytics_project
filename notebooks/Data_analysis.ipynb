# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/alden/OneDrive/Desktop/Python data science/IEEE CIS Fraud detection/df_transaction1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590540 entries, 0 to 590539
# Columns: 434 entries, transaction_id to device_info
# dtypes: float64(399), int64(4), object(31)
# memory usage: 1.9+ GB

# %%
df['isFraud'].value_counts(normalize=True)
# Out:
# isFraud
# 0    0.96501
# 1    0.03499
# Name: proportion, dtype: float64

# %%
df.head(5)
# Out:
#    transaction_id  isFraud  transaction_seconds_since_ref  transaction_amount  \
# 0         2987000        0                          86400                68.5
# 1         2987001        0                          86401                29.0
# 2         2987002        0                          86469                59.0
# 3         2987003        0                          86499                50.0
# 4         2987004        0                          86506                50.0
#
#   product_code  card_pan_hash  card_bin_group  card_issuer_country  \
# 0            W          13926             NaN                150.0
# 1            W           2755           404.0                150.0
# 2            W           4663           490.0                150.0
# 3            W          18132           567.0                150.0
# 4            H           4497           514.0                150.0
#
#    card_brand  card_category  ...                id_31  id_32      id_33  \
# ...

# %%
df.describe()
# Out:
#        transaction_id        isFraud  transaction_seconds_since_ref  \
# count    5.905400e+05  590540.000000                   5.905400e+05
# mean     3.282270e+06       0.034990                   7.372311e+06
# std      1.704744e+05       0.183755                   4.617224e+06
# min      2.987000e+06       0.000000                   8.640000e+04
# 25%      3.134635e+06       0.000000                   3.027058e+06
# 50%      3.282270e+06       0.000000                   7.306528e+06
# 75%      3.429904e+06       0.000000                   1.124662e+07
# max      3.577539e+06       1.000000                   1.581113e+07
#
#        transaction_amount  card_pan_hash  card_bin_group  card_issuer_country  \
# count       590540.000000  590540.000000   581607.000000        588975.000000
# mean           135.027176    9898.734658      362.555488           153.194925
# std            239.162522    4901.170153      157.793246            11.336444
# ...

# %%
sns.countplot(x='isFraud', data=df)
# Out:
# <Axes: xlabel='isFraud', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# transaction_id                        0
# isFraud                               0
# transaction_seconds_since_ref         0
# transaction_amount                    0
# product_code                          0
#                                   ...
# id_36                            449555
# id_37                            449555
# id_38                            449555
# device_type                      449730
# device_info                      471874
# Length: 434, dtype: int64

# %%
sns.displot(df['transaction_amount'], bins=50, kde=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_c = pd.DataFrame(df[df['isFraud'] == 1])

# %%
df_c.head()
# Out:
#      transaction_id  isFraud  transaction_seconds_since_ref  \
# 203         2987203        1                          89760
# 240         2987240        1                          90193
# 243         2987243        1                          90246
# 245         2987245        1                          90295
# 288         2987288        1                          90986
#
#      transaction_amount product_code  card_pan_hash  card_bin_group  \
# 203             445.000            W          18268           583.0
# 240              37.098            C          13413           103.0
# 243              37.098            C          13413           103.0
# 245              37.098            C          13413           103.0
# 288             155.521            C          16578           545.0
#
#      card_issuer_country card_brand  card_category  ...  \
# 203                150.0       visa          226.0  ...
# 240                185.0       visa          137.0  ...
# ...

# %%
sample_df = df.sample(n=100000, random_state=42)
corr_target = sample_df.select_dtypes(include=['number']).corr()['isFraud'].sort_values(ascending=False)

# %%
print(corr_target)
# Out:
# isFraud                       1.000000
# V257                          0.365644
# V246                          0.346830
# V244                          0.344396
# V242                          0.341745
#                                 ...
# V90                          -0.112530
# V49                          -0.114442
# V48                          -0.119054
# billing_cycle_days           -0.128485
# days_since_password_change   -0.145473
# Name: isFraud, Length: 403, dtype: float64

# %%
corr_target_df = pd.DataFrame(corr_target).reset_index()
corr_target_df.columns = ['Feature', 'Correlation']
corr_target_df.set_index('Feature', inplace=True)

# %%
plt.figure(figsize=(6, len(corr_target_df)*0.5))  # adjust height
sns.heatmap(corr_target_df, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation with Outcome')
# Out:
# Text(0.5, 1.0, 'Correlation with Outcome')

# %%
from sklearn.preprocessing import StandardScaler
df_numeric = df.select_dtypes(include=['number'])
scaler = StandardScaler()
scaler.fit(df_numeric)
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(df_numeric)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
df_numeric_filled = df_numeric.fillna(df_numeric.mean())
scaled_data = scaler.transform(df_numeric_filled)
pca.fit(df_numeric_filled)
# Out:
# PCA(n_components=2)

# %%
x_pca = pca.transform(scaled_data)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
scaled_data.shape
# Out:
# (590540, 403)

# %%
x_pca = pca.transform(scaled_data)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
x_pca.shape
# Out:
# (590540, 2)

# %%
plt.figure(figsize=(8,3))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df_numeric_filled['isFraud'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
df_numeric_filled['isFraud'].value_counts()
# Out:
# isFraud
# 0    569877
# 1     20663
# Name: count, dtype: int64

# %%
scaled_data.shape
# Out:
# (590540, 403)

# %%
df2 = pd.DataFrame(df_numeric_filled, columns=df_numeric.columns)

# %%
df2.head()
# Out:
#    transaction_id  isFraud  transaction_seconds_since_ref  transaction_amount  \
# 0         2987000        0                          86400                68.5
# 1         2987001        0                          86401                29.0
# 2         2987002        0                          86469                59.0
# 3         2987003        0                          86499                50.0
# 4         2987004        0                          86506                50.0
#
#    card_pan_hash  card_bin_group  card_issuer_country  card_category  \
# 0          13926      362.555488                150.0          142.0
# 1           2755      404.000000                150.0          102.0
# 2           4663      490.000000                150.0          166.0
# 3          18132      567.000000                150.0          117.0
# 4           4497      514.000000                150.0          102.0
#
#    billing_addr_city  billing_addr_state  ...       id_17      id_18  \
# ...

# %% [markdown]
# Logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X = df2.drop('isFraud', axis=1)
y = df2['isFraud']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
log_model.fit(X_train, y_train)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = log_model.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98    170905
#            1       0.29      0.00      0.01      6257
#
#     accuracy                           0.96    177162
#    macro avg       0.63      0.50      0.49    177162
# weighted avg       0.94      0.96      0.95    177162

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[170861,     44],
#        [  6239,     18]])
